# %%
# Import required libraries
import pandas as pd
from columns_name import a

# %%
sheet_name = pd.ExcelFile("f923_2022/EIA923_Schedules_2_3_4_5_M_12_2022_21FEB2023.xlsx").sheet_names

# %%
df= pd.read_excel("f923_2022/EIA923_Schedules_2_3_4_5_M_12_2022_21FEB2023.xlsx",sheet_name=sheet_name[1])

# %%
# Coloumns under year to data would be dropped
# They can be recreated using the time series data
# Dropping them would reduce the files size and the cost storing the data on the cloud
df = df.astype(str)

# I am storing all columns as string because null is represented with "." in some columns
# This would make converting the data type to numeric value give error since python can convert string to number.
a[:-6]

# %%
import os

os.system("wget https://www.eia.gov/electricity/data/eia923/xls/f923_2022.zip -o output.zip")
# Out:
# 0

# %%
from zipfile import ZipFile

df_zip = ZipFile('output.zip')

# %%
from pathlib import Path
path = Path(df_zip.extract(df_zip.filelist[0].filename,'data')).as_posix()

# %%
path
# Out:
# 'data/EIA923_Schedules_2_3_4_5_M_12_2022_21FEB2023.xlsx'

# %%
sheet_list = pd.ExcelFile(df_zip.filelist[0].filename).sheet_names

# %%
sheet_list
# Out:
# ['Page 1 Generation and Fuel Data',
#  'Page 1 Puerto Rico',
#  'Page 1 Energy Storage',
#  'Page 2 Stocks Data',
#  'Page 2 Oil Stocks Data',
#  'Page 3 Boiler Fuel Data',
#  'Page 4 Generator Data',
#  'Page 5 Fuel Receipts and Costs',
#  'Page 6 Plant Frame',
#  'Page 6 Plant Frame Puerto Rico',
#  'Page 7 File Layout']

# %%
type(sheet_list)
# Out:
# list

# %%
print([1,2,3] == [1,3,2])
# Out:
# False

# %%
import etl_web_to_gcs_setting

# %%
a = list(df.iloc[4])

# %%
import numpy as np

df[df.apply(lambda row: row.tolist() == a, axis=1)].index[0]
# Out:
# 4

# %%
df.columns = a
df.drop(df.index[:5], inplace=True)

# %%
df.head()
# Out:
#                                             Plant Id  \
# 0  EIA-923 Puerto Rico Monthly Generation and Fue...
# 1               Sources: EIA-923 and EIA-860 Reports
# 2  Note: Generation and fuel consumption data col...
# 3                                                nan
# 4                                           Plant Id
#
#    Combined Heat And\nPower Plant  Nuclear Unit Id  Plant Name  Operator Name  \
# 0                             nan              nan         nan            nan
# 1                             nan              nan         nan            nan
# 2                             nan              nan         nan            nan
# 3                             nan              nan         nan            nan
# 4  Combined Heat And\nPower Plant  Nuclear Unit Id  Plant Name  Operator Name
#
#    Operator Id  Plant State  Census Region  NERC Region  Reserved  ...  \
# 0          nan          nan            nan          nan       nan  ...
# ...

# %%
# Out:
#    Plant Id Combined Heat And\nPower Plant Nuclear Unit Id  \
# 5     61014                              N               .
# 6     61034                              Y               .
# 7     61034                              Y               .
# 8     61034                              Y               .
# 9     61034                              Y               .
# 10    61036                              N               .
# 11    61082                              N               .
# 12    61082                              N               .
# 13    61083                              N               .
# 14    61083                              N               .
# 15    61110                              N               .
# 16    61110                              N               .
# 17    61110                              N               .
# 18    61133                              N               .
# 19    61146                              Y               .
# ...
